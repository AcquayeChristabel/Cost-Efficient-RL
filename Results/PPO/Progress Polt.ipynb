# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_PPO = pd.read_csv("/content/drive/MyDrive/742_WaterWorld/Copy of progress_PPO_Normal.csv")
df_DDPG = pd.read_csv("/content/drive/MyDrive/742_WaterWorld/Copy of progress_DDPG_Normal.csv")

# %%
df_PPO.plot(x='episodes_total', y='episode_reward_mean')
df_DDPG.plot(x='episodes_total', y='episode_reward_mean')
# Out:
# <Axes: xlabel='episodes_total'>

# %%
df_gw = pd.read_csv("/content/drive/MyDrive/742_WaterWorld/log.csv")

df_gw.drop_duplicates(inplace=True)
df_gw.drop(1, inplace=True)

df_gw['frames'] = pd.to_numeric(df_gw['frames'])
df_gw['rreturn_mean'] = pd.to_numeric(df_gw['rreturn_mean'])

# %%
df_gw.plot(x='frames', y='rreturn_mean')
# Out:
# <Axes: xlabel='frames'>

# %%
# Out:
# 0      3073.609974172892
# 2     3294.7667245205002
# 4     2972.9581927599093
# 6     3474.0831392038103
# 8      2969.940307548477
# 10     3408.128067239427
# 12     3399.719230921454
# 14     3309.716110502977
# 16     3297.799975199127
# 18    3582.8536382716748
# 19    3193.3815796615363
# 20     3316.532244544958
# 21    3476.3692474554323
# 22     3389.020984472721
# 23     3268.688877430844
# 24     3317.451896388121
# 25     3358.650974074849
# 26     3407.122324952304
# 27    3328.2310112126206
# 28    3481.3426947986154
# 29     3206.723865001497
# 30    3372.5867434737593
# 31    3385.8884209223484
# 32    3464.8694621666855
# 33    3288.1139296131555
# 34    3238.4100951700198
# 35     3378.852311168313
# 36     3276.193862143273
# 37    3057.4515509477105
# 38    3335.6508032417028
# 39    3418.5542517547583
# 40     3429.067694463351
# 41    3323.1540848799596
# 42    3266.0938444498606
# 43     3347.518994879309
# 44     3051.643723033691
# 45    3225.0528034144522
# ...
